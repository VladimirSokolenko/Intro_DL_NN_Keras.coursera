# %% [markdown]
# # Step C. Move to 100 epochs from 50
# 1. Baseline model
# 2. Features normalization added
# 3. Train model using 100 epochs
#
# Install required libraries

# %%
# All Libraries required for this notebook are listed below.
# If you doesn't have the libraries preinstalled, you may need to uncomment and install certain libraries.

#!pip install numpy
#!pip install pandas
#!pip install keras
#!pip install sklearn

# %% [markdown]
# ## Preparation stage
# Import required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Download the concrete dataset

# %%
concrete_data = pd.read_csv('https://cocl.us/concrete_data')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# Let's see the dataset description and check for any missing values

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# There is no any missing data

# %% [markdown]
# # Create model
# Import all needed packages from Keras

# %%
from keras.models import Sequential
from keras.layers import InputLayer
from keras.layers import Dense

# %% [markdown]
# Define a model. We define a function that describes our regression model so that we can conveniently call it to create our model.
#
# The function create a model that:
# - Has one hidden layer of 10 nodes, and a ReLU activation function
# - Use the adam optimizer and the mean squared error as the loss function.

# %%
# define regression model
def regression_model(input_shape):
    # create model
    model = Sequential()
    model.add(InputLayer(shape=input_shape))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['root_mean_squared_error'])
    return model

# %% [markdown]
# # 1. Split data
# a) Split data to features (predictors) and Y (targets)

# %%
concrete_data_columns = concrete_data.columns

features = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
Y = concrete_data['Strength'] # Strength column

# %% [markdown]
# b) features normalization

# %%
features_norm = (features - features.mean()) / features.std() # features normalization
features_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# c) Split data into Train and Test datasets
#
# We randomly split the data into a training and test sets by holding 30% of the data for testing, using the *train_test_split* helper function from Scikit-learn.
#
# Now use the normalized features data.

# %%
from sklearn.model_selection import train_test_split # load train_test_split from preinstalled sklearn library
x_train, x_test, y_train, y_test = train_test_split(features_norm, Y, test_size=0.3)

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = features_norm.shape[1] # number of features
print(n_cols)
# Out:
# 8

# %% [markdown]
# ## 2. Train model

# %% [markdown]
# Call the function to create the model.

# %%
# build the model
model = regression_model(input_shape=(n_cols,))

# %% [markdown]
# Train and validate the model at the same time using the *fit* method with **train** and **test** data

# %%
# fit the model
history = model.fit(x_train, y_train, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 28ms/step - loss: 1560.7607 - root_mean_squared_error: 39.4205
# Epoch 2/100
# 23/23 - 0s - 1ms/step - loss: 1534.1882 - root_mean_squared_error: 39.1989
# Epoch 3/100
# 23/23 - 0s - 2ms/step - loss: 1515.6993 - root_mean_squared_error: 38.9659
# Epoch 4/100
# 23/23 - 0s - 1ms/step - loss: 1507.3250 - root_mean_squared_error: 38.7224
# Epoch 5/100
# 23/23 - 0s - 2ms/step - loss: 1483.3550 - root_mean_squared_error: 38.4616
# Epoch 6/100
# 23/23 - 0s - 2ms/step - loss: 1465.3264 - root_mean_squared_error: 38.1877
# Epoch 7/100
# 23/23 - 0s - 2ms/step - loss: 1428.2211 - root_mean_squared_error: 37.8971
# Epoch 8/100
# 23/23 - 0s - 2ms/step - loss: 1408.9645 - root_mean_squared_error: 37.5918
# Epoch 9/100
# 23/23 - 0s - 1ms/step - loss: 1393.3920 - root_mean_squared_error: 37.2636
# Epoch 10/100
# 23/23 - 0s - 1ms/step - loss: 1360.4268 - root_mean_squared_error: 36.9205
# Epoch 11/100
# 23/23 - 0s - 1ms/step - loss: 1334.3477 - root_mean_squared_error: 36.5573
# Epoch 12/100
# 23/23 - 0s - 1ms/step - loss: 1320.9072 - root_mean_squared_error: 36.1800
# Epoch 13/100
# 23/23 - 0s - 2ms/step - loss: 1280.8953 - root_mean_squared_error: 35.7787
# Epoch 14/100
# 23/23 - 0s - 1ms/step - loss: 1254.3018 - root_mean_squared_error: 35.3550
# Epoch 15/100
# 23/23 - 0s - 1ms/step - loss: 1227.3937 - root_mean_squared_error: 34.9188
# Epoch 16/100
# 23/23 - 0s - 2ms/step - loss: 1183.9159 - root_mean_squared_error: 34.4620
# Epoch 17/100
# 23/23 - 0s - 1ms/step - loss: 1154.4388 - root_mean_squared_error: 33.9894
# Epoch 18/100
# 23/23 - 0s - 1ms/step - loss: 1118.7903 - root_mean_squared_error: 33.5005
# Epoch 19/100
# 23/23 - 0s - 1ms/step - loss: 1089.2094 - root_mean_squared_error: 32.9978
# Epoch 20/100
# 23/23 - 0s - 1ms/step - loss: 1055.4530 - root_mean_squared_error: 32.4781
# Epoch 21/100
# 23/23 - 0s - 1ms/step - loss: 1024.4435 - root_mean_squared_error: 31.9398
# Epoch 22/100
# 23/23 - 0s - 1ms/step - loss: 984.9657 - root_mean_squared_error: 31.3968
# Epoch 23/100
# 23/23 - 0s - 1ms/step - loss: 947.4271 - root_mean_squared_error: 30.8343
# Epoch 24/100
# 23/23 - 0s - 1ms/step - loss: 913.8909 - root_mean_squared_error: 30.2607
# Epoch 25/100
# 23/23 - 0s - 1ms/step - loss: 886.8272 - root_mean_squared_error: 29.6808
# Epoch 26/100
# 23/23 - 0s - 1ms/step - loss: 845.2446 - root_mean_squared_error: 29.0931
# Epoch 27/100
# 23/23 - 0s - 1ms/step - loss: 806.9551 - root_mean_squared_error: 28.4825
# Epoch 28/100
# 23/23 - 0s - 1ms/step - loss: 777.3073 - root_mean_squared_error: 27.8843
# Epoch 29/100
# 23/23 - 0s - 2ms/step - loss: 739.0887 - root_mean_squared_error: 27.2674
# Epoch 30/100
# 23/23 - 0s - 2ms/step - loss: 709.2003 - root_mean_squared_error: 26.6494
# Epoch 31/100
# 23/23 - 0s - 2ms/step - loss: 681.1878 - root_mean_squared_error: 26.0356
# Epoch 32/100
# 23/23 - 0s - 1ms/step - loss: 644.4058 - root_mean_squared_error: 25.4198
# Epoch 33/100
# 23/23 - 0s - 1ms/step - loss: 617.0779 - root_mean_squared_error: 24.8070
# Epoch 34/100
# 23/23 - 0s - 1ms/step - loss: 581.1791 - root_mean_squared_error: 24.2051
# Epoch 35/100
# 23/23 - 0s - 1ms/step - loss: 559.5788 - root_mean_squared_error: 23.6169
# Epoch 36/100
# 23/23 - 0s - 1ms/step - loss: 526.2006 - root_mean_squared_error: 23.0347
# Epoch 37/100
# 23/23 - 0s - 1ms/step - loss: 507.9285 - root_mean_squared_error: 22.4677
# Epoch 38/100
# 23/23 - 0s - 2ms/step - loss: 478.5879 - root_mean_squared_error: 21.9189
# Epoch 39/100
# 23/23 - 0s - 2ms/step - loss: 454.0167 - root_mean_squared_error: 21.3804
# Epoch 40/100
# 23/23 - 0s - 2ms/step - loss: 440.8448 - root_mean_squared_error: 20.8727
# Epoch 41/100
# 23/23 - 0s - 2ms/step - loss: 413.3032 - root_mean_squared_error: 20.3652
# Epoch 42/100
# 23/23 - 0s - 2ms/step - loss: 392.5157 - root_mean_squared_error: 19.8971
# Epoch 43/100
# 23/23 - 0s - 2ms/step - loss: 376.2181 - root_mean_squared_error: 19.4390
# Epoch 44/100
# 23/23 - 0s - 1ms/step - loss: 359.3561 - root_mean_squared_error: 19.0046
# Epoch 45/100
# 23/23 - 0s - 1ms/step - loss: 345.1572 - root_mean_squared_error: 18.5912
# Epoch 46/100
# 23/23 - 0s - 1ms/step - loss: 329.6293 - root_mean_squared_error: 18.2019
# Epoch 47/100
# 23/23 - 0s - 1ms/step - loss: 317.6556 - root_mean_squared_error: 17.8310
# Epoch 48/100
# 23/23 - 0s - 2ms/step - loss: 303.9714 - root_mean_squared_error: 17.4811
# Epoch 49/100
# 23/23 - 0s - 2ms/step - loss: 292.2893 - root_mean_squared_error: 17.1512
# Epoch 50/100
# 23/23 - 0s - 2ms/step - loss: 283.3819 - root_mean_squared_error: 16.8409
# Epoch 51/100
# 23/23 - 0s - 2ms/step - loss: 272.1820 - root_mean_squared_error: 16.5566
# Epoch 52/100
# 23/23 - 0s - 1ms/step - loss: 263.4663 - root_mean_squared_error: 16.2833
# Epoch 53/100
# 23/23 - 0s - 1ms/step - loss: 256.1049 - root_mean_squared_error: 16.0304
# Epoch 54/100
# 23/23 - 0s - 1ms/step - loss: 248.6842 - root_mean_squared_error: 15.7959
# Epoch 55/100
# 23/23 - 0s - 1ms/step - loss: 241.5425 - root_mean_squared_error: 15.5771
# Epoch 56/100
# 23/23 - 0s - 1ms/step - loss: 236.0511 - root_mean_squared_error: 15.3723
# Epoch 57/100
# 23/23 - 0s - 1ms/step - loss: 229.6538 - root_mean_squared_error: 15.1824
# Epoch 58/100
# 23/23 - 0s - 1ms/step - loss: 226.0947 - root_mean_squared_error: 15.0031
# Epoch 59/100
# 23/23 - 0s - 2ms/step - loss: 218.9800 - root_mean_squared_error: 14.8432
# Epoch 60/100
# 23/23 - 0s - 2ms/step - loss: 217.7919 - root_mean_squared_error: 14.6882
# Epoch 61/100
# 23/23 - 0s - 2ms/step - loss: 211.8815 - root_mean_squared_error: 14.5429
# Epoch 62/100
# 23/23 - 0s - 2ms/step - loss: 208.4085 - root_mean_squared_error: 14.4105
# Epoch 63/100
# 23/23 - 0s - 2ms/step - loss: 202.2972 - root_mean_squared_error: 14.2863
# Epoch 64/100
# 23/23 - 0s - 1ms/step - loss: 201.9620 - root_mean_squared_error: 14.1678
# Epoch 65/100
# 23/23 - 0s - 1ms/step - loss: 195.8042 - root_mean_squared_error: 14.0587
# Epoch 66/100
# 23/23 - 0s - 1ms/step - loss: 194.1311 - root_mean_squared_error: 13.9595
# Epoch 67/100
# 23/23 - 0s - 1ms/step - loss: 192.3412 - root_mean_squared_error: 13.8653
# Epoch 68/100
# 23/23 - 0s - 1ms/step - loss: 189.3187 - root_mean_squared_error: 13.7799
# Epoch 69/100
# 23/23 - 0s - 1ms/step - loss: 187.7309 - root_mean_squared_error: 13.7026
# Epoch 70/100
# 23/23 - 0s - 1ms/step - loss: 188.1856 - root_mean_squared_error: 13.6262
# Epoch 71/100
# 23/23 - 0s - 1ms/step - loss: 183.0905 - root_mean_squared_error: 13.5577
# Epoch 72/100
# 23/23 - 0s - 1ms/step - loss: 181.3592 - root_mean_squared_error: 13.4906
# Epoch 73/100
# 23/23 - 0s - 1ms/step - loss: 179.8329 - root_mean_squared_error: 13.4284
# Epoch 74/100
# 23/23 - 0s - 2ms/step - loss: 178.3588 - root_mean_squared_error: 13.3699
# Epoch 75/100
# 23/23 - 0s - 1ms/step - loss: 178.0722 - root_mean_squared_error: 13.3112
# Epoch 76/100
# 23/23 - 0s - 1ms/step - loss: 174.6279 - root_mean_squared_error: 13.2610
# Epoch 77/100
# 23/23 - 0s - 1ms/step - loss: 173.5675 - root_mean_squared_error: 13.2112
# Epoch 78/100
# 23/23 - 0s - 1ms/step - loss: 173.1209 - root_mean_squared_error: 13.1593
# Epoch 79/100
# 23/23 - 0s - 1ms/step - loss: 170.2251 - root_mean_squared_error: 13.1106
# Epoch 80/100
# 23/23 - 0s - 1ms/step - loss: 172.1810 - root_mean_squared_error: 13.0701
# Epoch 81/100
# 23/23 - 0s - 1ms/step - loss: 170.5941 - root_mean_squared_error: 13.0232
# Epoch 82/100
# 23/23 - 0s - 1ms/step - loss: 169.2934 - root_mean_squared_error: 12.9768
# Epoch 83/100
# 23/23 - 0s - 1ms/step - loss: 166.2345 - root_mean_squared_error: 12.9356
# Epoch 84/100
# 23/23 - 0s - 1ms/step - loss: 164.6779 - root_mean_squared_error: 12.9010
# Epoch 85/100
# 23/23 - 0s - 1ms/step - loss: 164.6735 - root_mean_squared_error: 12.8574
# Epoch 86/100
# 23/23 - 0s - 1ms/step - loss: 165.5023 - root_mean_squared_error: 12.8171
# Epoch 87/100
# 23/23 - 0s - 1ms/step - loss: 164.5785 - root_mean_squared_error: 12.7796
# Epoch 88/100
# 23/23 - 0s - 2ms/step - loss: 162.1955 - root_mean_squared_error: 12.7388
# Epoch 89/100
# 23/23 - 0s - 1ms/step - loss: 161.9895 - root_mean_squared_error: 12.7019
# Epoch 90/100
# 23/23 - 0s - 1ms/step - loss: 161.2244 - root_mean_squared_error: 12.6627
# Epoch 91/100
# 23/23 - 0s - 1ms/step - loss: 157.7062 - root_mean_squared_error: 12.6274
# Epoch 92/100
# 23/23 - 0s - 1ms/step - loss: 158.2705 - root_mean_squared_error: 12.5888
# Epoch 93/100
# 23/23 - 0s - 1ms/step - loss: 155.9056 - root_mean_squared_error: 12.5519
# Epoch 94/100
# 23/23 - 0s - 1ms/step - loss: 156.8950 - root_mean_squared_error: 12.5159
# Epoch 95/100
# 23/23 - 0s - 1ms/step - loss: 156.2005 - root_mean_squared_error: 12.4829
# Epoch 96/100
# 23/23 - 0s - 1ms/step - loss: 154.2549 - root_mean_squared_error: 12.4441
# Epoch 97/100
# 23/23 - 0s - 1ms/step - loss: 153.0581 - root_mean_squared_error: 12.4105
# Epoch 98/100
# 23/23 - 0s - 1ms/step - loss: 154.1677 - root_mean_squared_error: 12.3757
# Epoch 99/100
# 23/23 - 0s - 1ms/step - loss: 152.8941 - root_mean_squared_error: 12.3387
# Epoch 100/100
# 23/23 - 0s - 1ms/step - loss: 150.1420 - root_mean_squared_error: 12.3024

# %% [markdown]
# # 3. Model evaluation and show metrics  (RMSE)
#
# The evaluation result (*score*) is array with two elements in our case - the *loss_value* (score[0]) and the *root_mean_squared_error* value (score[1])

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Evaluation Root Mean Squared Error:', score[1])
# Out:
# Evaluation Root Mean Squared Error: 12.661166191101074

# %% [markdown]
# # 4.Repeating steps 1...3 for 50 times
# Repeat steps 1...3 and collect metrics in one list

# %%
# build the model
model = regression_model(input_shape=(n_cols,))

rmse_list = []
print('Iterations calculation started')
for step in range(50): # Cycle of iterations for splitting, learning and evaluation stages
    # print('Iteration: ', step, end='\r')
    x_train, x_test, y_train, y_test = train_test_split(features, Y, test_size=0.3) 
    # fit the model
    history = model.fit(x_train, y_train, epochs=100, verbose=0)
    score = model.evaluate(x_test, y_test, verbose=0)
    print('Evaluation Root Mean Squared Error', 'for iteration', step+1, '=', score[1], end='\r')
    rmse_list.append(score[1]) # adding to the RMSE list current iteration metric
# print(rmse_list) #print list of calculated RMSE
# Out:
# Iterations calculation started
# Evaluation Root Mean Squared Error for iteration 50 = 6.1295237541198735

# %% [markdown]
# Calculate mean and standard deviation for the calculated metrics

# %%
mean_rmse = np.mean(np.array(rmse_list))
mean_std = np.std(np.array(rmse_list))
print('Mean RMSE = ', mean_rmse)
print('Standard deviation of RMSE = ', mean_std)
# Out:
# Mean RMSE =  6.776899356842041
# Standard deviation of RMSE =  0.6646612340822166
